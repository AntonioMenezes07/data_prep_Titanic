# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioMenezes07/data_prep_Titanic/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**importando a base de dados**

# %%
import pandas as pd
df = pd.read_csv('/content/train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
lista_spec = ['PassengerId', 'Survived']

# %%
df01 = df.drop(lista_spec,axis = 1)
df01
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %% [markdown]
# ##**extraindo titulo dos nomes**

# %%
df01['titulo'] = df01['Name'].str.extract(' (Mr\.|Miss\.|Mrs\.|Dr\.) ')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipython-input-2813906765.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df01['titulo'] = df01['Name'].str.extract(' (Mr\.|Miss\.|Mrs\.|Dr\.) ')

# %%
df01 = df01.drop('Name',axis = 1)
df01
# Out:
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 2         3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         1  female  35.0      1      0            113803  53.1000  C123
# 4         3    male  35.0      0      0            373450   8.0500   NaN
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 886       2    male  27.0      0      0            211536  13.0000   NaN
# 887       1  female  19.0      0      0            112053  30.0000   B42
# 888       3  female   NaN      1      2        W./C. 6607  23.4500   NaN
# 889       1    male  26.0      0      0            111369  30.0000  C148
# 890       3    male  32.0      0      0            370376   7.7500   NaN
#
#     Embarked titulo
# 0          S    Mr.
# 1          C   Mrs.
# 2          S  Miss.
# ...

# %% [markdown]
# ##**Metadados**

# %%
metadados = pd.DataFrame({'colunas': df01.columns, 'tipo': df01.dtypes, 'cardinalidade': df01.nunique(),'qtd_nulos' : df01.isnull().sum() ,'percent_nulos': round((df01.isnull().sum()/len(df01))*100,2)})
metadados=metadados.sort_values(by='percent_nulos',ascending=False)
metadados = metadados.reset_index(drop=True)
metadados
# Out:
#     colunas     tipo  cardinalidade  qtd_nulos  percent_nulos
# 0     Cabin   object            147        687          77.10
# 1       Age  float64             88        177          19.87
# 2    titulo   object              4         60           6.73
# 3  Embarked   object              3          2           0.22
# 4       Sex   object              2          0           0.00
# 5    Pclass    int64              3          0           0.00
# 6    Ticket   object            681          0           0.00
# 7     Parch    int64              7          0           0.00
# 8     SibSp    int64              7          0           0.00
# 9      Fare  float64            248          0           0.00

# %% [markdown]
# ##**dropando colunas com mais de 75% de valores nulos**

# %%
df_drop_nulos = metadados[metadados['percent_nulos']>= 75]
lista_drop_nulos = list(df_drop_nulos['colunas'])
lista_drop_nulos
# Out:
# ['Cabin']

# %%
df01 = df01.drop(df_drop_nulos['colunas'], axis = 1)
df01
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-420064529.py in <cell line: 0>()
# ----> 1 df01 = df01.drop(df_drop_nulos['colunas'], axis = 1)
#       2 df01
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %% [markdown]
# ##**tratamento de valores nulos**

# %% [markdown]
# ####**variaveis numericas**
# trocar pela media

# %%
df01 = df01.fillna(df01.select_dtypes(include=['int64', 'float64']).mean())
df01
# Out:
#      Pclass     Sex        Age  SibSp  Parch            Ticket     Fare  \
# 0         3    male  22.000000      1      0         A/5 21171   7.2500
# 1         1  female  38.000000      1      0          PC 17599  71.2833
# 2         3  female  26.000000      0      0  STON/O2. 3101282   7.9250
# 3         1  female  35.000000      1      0            113803  53.1000
# 4         3    male  35.000000      0      0            373450   8.0500
# ..      ...     ...        ...    ...    ...               ...      ...
# 886       2    male  27.000000      0      0            211536  13.0000
# 887       1  female  19.000000      0      0            112053  30.0000
# 888       3  female  29.699118      1      2        W./C. 6607  23.4500
# 889       1    male  26.000000      0      0            111369  30.0000
# 890       3    male  32.000000      0      0            370376   7.7500
#
#     Embarked titulo
# 0          S    Mr.
# 1          C   Mrs.
# 2          S  Miss.
# ...

# %% [markdown]
# ####**variaveis categoricas**
# trocar por 'desconhecido'

# %%
df01[df01.select_dtypes(include=['object']).columns] = df01[df01.select_dtypes(include=['object']).columns].fillna('desconhecido')
df01
# Out:
#      Pclass     Sex        Age  SibSp  Parch            Ticket     Fare  \
# 0         3    male  22.000000      1      0         A/5 21171   7.2500
# 1         1  female  38.000000      1      0          PC 17599  71.2833
# 2         3  female  26.000000      0      0  STON/O2. 3101282   7.9250
# 3         1  female  35.000000      1      0            113803  53.1000
# 4         3    male  35.000000      0      0            373450   8.0500
# ..      ...     ...        ...    ...    ...               ...      ...
# 886       2    male  27.000000      0      0            211536  13.0000
# 887       1  female  19.000000      0      0            112053  30.0000
# 888       3  female  29.699118      1      2        W./C. 6607  23.4500
# 889       1    male  26.000000      0      0            111369  30.0000
# 890       3    male  32.000000      0      0            370376   7.7500
#
#     Embarked        titulo
# 0          S           Mr.
# 1          C          Mrs.
# ...

# %% [markdown]
# ##**normalizacao dos dados**
# z-score

# %%
from scipy.stats import zscore
df01[df01.select_dtypes(include = ['int64', 'float64']).columns] = df01[df01.select_dtypes(include = ['int64', 'float64']).columns].apply(zscore)
df01
# Out:
#        Pclass     Sex       Age     SibSp     Parch            Ticket  \
# 0    0.827377    male -0.592481  0.432793 -0.473674         A/5 21171
# 1   -1.566107  female  0.638789  0.432793 -0.473674          PC 17599
# 2    0.827377  female -0.284663 -0.474545 -0.473674  STON/O2. 3101282
# 3   -1.566107  female  0.407926  0.432793 -0.473674            113803
# 4    0.827377    male  0.407926 -0.474545 -0.473674            373450
# ..        ...     ...       ...       ...       ...               ...
# 886 -0.369365    male -0.207709 -0.474545 -0.473674            211536
# 887 -1.566107  female -0.823344 -0.474545 -0.473674            112053
# 888  0.827377  female  0.000000  0.432793  2.008933        W./C. 6607
# 889 -1.566107    male -0.284663 -0.474545 -0.473674            111369
# 890  0.827377    male  0.177063 -0.474545 -0.473674            370376
#
#          Fare Embarked        titulo
# 0   -0.502445        S           Mr.
# 1    0.786845        C          Mrs.
# ...

# %% [markdown]
# ###**aplicando o oneHotEnconding para variaveis categoricas com cardinalidade baixa**

# %%
from sklearn.preprocessing import OneHotEncoder
cardinalidade = 2
variaveis = metadados[(metadados['cardinalidade'] <= cardinalidade) & (metadados['tipo'] == 'object')]
variaveis = list(variaveis['colunas'])
variaveis
# Out:
# ['Sex']

# %%
# Instanciando o encoder
encoder = OneHotEncoder(drop='first', sparse_output=False)

# Aplicando o one-hot encoding
encoded_data = encoder.fit_transform(df01[variaveis])

encoded_cols = encoder.get_feature_names_out(variaveis)
encoded_df = pd.DataFrame(encoded_data, columns=encoded_cols, index=df01.index)

df01 = pd.concat([df01.drop(variaveis, axis=1), encoded_df], axis=1)

df01.head()
# Out:
#      Pclass       Age     SibSp     Parch            Ticket      Fare  \
# 0  0.827377 -0.592481  0.432793 -0.473674         A/5 21171 -0.502445
# 1 -1.566107  0.638789  0.432793 -0.473674          PC 17599  0.786845
# 2  0.827377 -0.284663 -0.474545 -0.473674  STON/O2. 3101282 -0.488854
# 3 -1.566107  0.407926  0.432793 -0.473674            113803  0.420730
# 4  0.827377  0.407926 -0.474545 -0.473674            373450 -0.486337
#
#   Embarked titulo  Sex_male
# 0        S    Mr.       1.0
# 1        C   Mrs.       0.0
# 2        S  Miss.       0.0
# 3        S   Mrs.       0.0
# 4        S    Mr.       1.0

# %% [markdown]
# ###**aplicando o label enconding para variaveis com alta cardinalidade**

# %%
cardinalidade = 2
variaveis02 = metadados[(metadados['cardinalidade'] > cardinalidade) & (metadados['tipo'] == 'object')]
variaveis02 = list(variaveis02['colunas'])
variaveis02


for item in lista_drop_nulos:
    if item in variaveis02:
        variaveis02.remove(item)
variaveis02
# Out:
# ['titulo', 'Embarked', 'Ticket']

# %%
from sklearn.preprocessing import LabelEncoder

for col in variaveis02:
    encoder = LabelEncoder()
    df01[col] = encoder.fit_transform(df01[col])

df01.head()

# Inner join usando o índice
df02 = pd.merge(df01, df[['Survived']], left_index=True, right_index=True, how='inner')
df02.shape
# Out:
# (891, 10)

# %%
df02
# Out:
#        Pclass       Age     SibSp     Parch  Ticket      Fare  Embarked  \
# 0    0.827377 -0.592481  0.432793 -0.473674     523 -0.502445         2
# 1   -1.566107  0.638789  0.432793 -0.473674     596  0.786845         0
# 2    0.827377 -0.284663 -0.474545 -0.473674     669 -0.488854         2
# 3   -1.566107  0.407926  0.432793 -0.473674      49  0.420730         2
# 4    0.827377  0.407926 -0.474545 -0.473674     472 -0.486337         2
# ..        ...       ...       ...       ...     ...       ...       ...
# 886 -0.369365 -0.207709 -0.474545 -0.473674     101 -0.386671         2
# 887 -1.566107 -0.823344 -0.474545 -0.473674      14 -0.044381         2
# 888  0.827377  0.000000  0.432793  2.008933     675 -0.176263         2
# 889 -1.566107 -0.284663 -0.474545 -0.473674       8 -0.044381         0
# 890  0.827377  0.177063 -0.474545 -0.473674     466 -0.492378         1
#
#      titulo  Sex_male  Survived
# 0         2       1.0         0
# 1         3       0.0         1
# ...
